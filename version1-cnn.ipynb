# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
import os
import matplotlib.gridspec as gridspec
import matplotlib.ticker as ticker
sns.set_style('whitegrid')
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../input/Data_Entry_2017.csv')
data = data[data['Patient Age']<100] #removing datapoints which having age greater than 100
data_image_paths = {os.path.basename(x): x for x in 
                   glob(os.path.join('..', 'input', 'images*', '*', '*.png'))}
print('Scans found:', len(data_image_paths), ', Total Headers', data.shape[0])
data['path'] = data['Image Index'].map(data_image_paths.get)
data['Patient Age'] = data['Patient Age'].map(lambda x: int(x))
data.sample(3)
# Out:
# Scans found: 112120 , Total Headers 112104
#              Image Index                     ...                                                              path
# 105560  00028380_007.png                     ...                       ../input/images_012/images/00028380_007.png
# 46727   00011925_052.png                     ...                       ../input/images_006/images/00011925_052.png
# 57599   00014270_000.png                     ...                       ../input/images_007/images/00014270_000.png
#
# [3 rows x 13 columns]

# %%
#data['Finding Labels'] = data['Finding Labels'].map(lambda x: x.replace('No Finding', ''))
from itertools import chain
all_labels = np.unique(list(chain(*data['Finding Labels'].map(lambda x: x.split('|')).tolist())))
all_labels = [x for x in all_labels if len(x)>0]
print('All Labels ({}): {}'.format(len(all_labels), all_labels))
for c_label in all_labels:
    if len(c_label)>1: # leave out empty labels
        data[c_label] = data['Finding Labels'].map(lambda finding: 1.0 if c_label in finding else 0)
data.sample(3)
# Out:
# All Labels (15): ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Effusion', 'Emphysema', 'Fibrosis', 'Hernia', 'Infiltration', 'Mass', 'No Finding', 'Nodule', 'Pleural_Thickening', 'Pneumonia', 'Pneumothorax']
#             Image Index Finding Labels      ...       Pneumonia  Pneumothorax
# 87660  00021663_004.png   Cardiomegaly      ...             0.0           0.0
# 98123  00025902_000.png    Atelectasis      ...             0.0           0.0
# 7098   00001877_000.png     No Finding      ...             0.0           0.0
#
# [3 rows x 28 columns]

# %%
data.sample(3)
# Out:
#             Image Index Finding Labels      ...       Pneumonia  Pneumothorax
# 29592  00007700_005.png     No Finding      ...             0.0           0.0
# 19125  00005070_003.png     No Finding      ...             0.0           0.0
# 92552  00023100_000.png     No Finding      ...             0.0           0.0
#
# [3 rows x 28 columns]

# %%
MIN_CASES = 0
all_labels = [c_label for c_label in all_labels if data[c_label].sum()>MIN_CASES]
print('Clean Labels ({})'.format(len(all_labels)), 
      [(c_label,int(data[c_label].sum())) for c_label in all_labels])
# Out:
# Clean Labels (15) [('Atelectasis', 11558), ('Cardiomegaly', 2776), ('Consolidation', 4667), ('Edema', 2302), ('Effusion', 13316), ('Emphysema', 2516), ('Fibrosis', 1686), ('Hernia', 227), ('Infiltration', 19891), ('Mass', 5779), ('No Finding', 60353), ('Nodule', 6331), ('Pleural_Thickening', 3384), ('Pneumonia', 1430), ('Pneumothorax', 5301)]

# %%
sample_weights = data['Finding Labels'].map(lambda x: len(x.split('|')) if len(x)>0 else 0).values + 4e-2
sample_weights /= sample_weights.sum()
data = data.sample(112104, weights=sample_weights)

label_counts = data['Finding Labels'].value_counts()[:15]
fig, ax1 = plt.subplots(1,1,figsize = (12, 8))
ax1.bar(np.arange(len(label_counts))+0.5, label_counts)
ax1.set_xticks(np.arange(len(label_counts))+0.5)
_ = ax1.set_xticklabels(label_counts.index, rotation = 90)

# %%
data['disease_vec'] = data.apply(lambda x: [x[all_labels].values], 1).map(lambda x: x[0])

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(data, 
                                   test_size = 0.20, 
                                   random_state = 20,
                                   stratify = data['Finding Labels'].map(lambda x: x[:4]))
print('train', train_df.shape[0], 'test', test_df.shape[0])
# Out:
# train 89683 test 22421

# %%
train_df, valid_df = train_test_split(train_df, 
                                   test_size = 0.10, 
                                   random_state = 20,
                                   stratify = train_df['Finding Labels'].map(lambda x: x[:4]))
print('train', train_df.shape[0], 'valid', valid_df.shape[0])
# Out:
# train 80714 valid 8969

# %%
from keras.preprocessing.image import ImageDataGenerator
IMG_SIZE = (128, 128)
core_idg = ImageDataGenerator(samplewise_center=True, 
                              samplewise_std_normalization=True, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range= 0.05, 
                              width_shift_range=0.1, 
                              rotation_range=5, 
                              shear_range = 0.1,
                              fill_mode = 'reflect',
                              zoom_range=0.15)
# Out:
# Using TensorFlow backend.

# %%
def flow_from_dataframe(img_data_gen, in_df, path_col, y_col, **dflow_args):
    base_dir = os.path.dirname(in_df[path_col].values[0])
    print('## Ignore next message from keras, values are replaced anyways')
    df_gen = img_data_gen.flow_from_directory(base_dir, 
                                     class_mode = 'sparse',
                                    **dflow_args)
    df_gen.filenames = in_df[path_col].values
    df_gen.classes = np.stack(in_df[y_col].values)
    df_gen.samples = in_df.shape[0]
    df_gen.n = in_df.shape[0]
    df_gen._set_index_array()
    df_gen.directory = '' # since we have the full path
    print('Reinserting dataframe: {} images'.format(in_df.shape[0]))
    return df_gen

# %%
train_gen = flow_from_dataframe(core_idg, train_df, 
                             path_col = 'path',
                            y_col = 'disease_vec', 
                            target_size = IMG_SIZE,
                             color_mode = 'grayscale',
                            batch_size = 16)

valid_gen = flow_from_dataframe(core_idg, valid_df, 
                             path_col = 'path',
                            y_col = 'disease_vec', 
                            target_size = IMG_SIZE,
                             color_mode = 'grayscale',
                            batch_size = 16) # we can use much larger batches for evaluation
# used a fixed dataset for evaluating the algorithm
test_X, test_Y = next(flow_from_dataframe(core_idg, 
                               test_df, 
                             path_col = 'path',
                            y_col = 'disease_vec', 
                            target_size = IMG_SIZE,
                             color_mode = 'grayscale',
                            batch_size = 1024)) # one big batch
# Out:
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 80714 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 8969 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 22421 images

# %%
t_x, t_y = next(train_gen)
fig, m_axs = plt.subplots(4, 4, figsize = (16, 16))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone', vmin = -1.5, vmax = 1.5)
    c_ax.set_title(', '.join([n_class for n_class, n_score in zip(all_labels, c_y) 
                             if n_score>0.5]))
    c_ax.axis('off')

# %%
from keras import backend as K

def binary_accuracy(y_true, y_pred):
    return K.mean(K.equal(y_true, K.round(y_pred)))
        
def precision_threshold(threshold = 0.5):
    def precision(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(y_pred)
        precision_ratio = true_positives / (predicted_positives + K.epsilon())
        return precision_ratio
    return precision

def recall_threshold(threshold = 0.5):
    def recall(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.clip(y_true, 0, 1))
        recall_ratio = true_positives / (possible_positives + K.epsilon())
        return recall_ratio
    return recall

def fbeta_score_threshold(beta = 1, threshold = 0.5):
    def fbeta_score(y_true, y_pred):
        threshold_value = threshold
        beta_value = beta
        p = precision_threshold(threshold_value)(y_true, y_pred)
        r = recall_threshold(threshold_value)(y_true, y_pred)
        bb = beta_value ** 2
        fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
        return fbeta_score
    return fbeta_score

# %%
##################################temporary

from keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten, Conv2D
from keras.models import Sequential

multi_disease_model = Sequential()
multi_disease_model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=t_x.shape[1:]))
multi_disease_model.add(GlobalAveragePooling2D())
multi_disease_model.add(Dropout(0.5))
multi_disease_model.add(Dense(512))
multi_disease_model.add(Dropout(0.5))
multi_disease_model.add(Dense(len(all_labels), activation = 'sigmoid'))
multi_disease_model.compile(optimizer = 'adam', loss = 'binary_crossentropy',
                           metrics=[precision_threshold(threshold = 0.5), 
                           recall_threshold(threshold = 0.5), 
                           fbeta_score_threshold(beta=0.5, threshold = 0.5),
                          'accuracy'])
multi_disease_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 126, 126, 32)      320
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 32)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               16896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 15)                7695
# =================================================================
# Total params: 24,911
# Trainable params: 24,911
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = multi_disease_model.fit_generator(train_gen, 
                                  steps_per_epoch=100,
                                  validation_data = valid_gen, 
                                  validation_steps = 20,
                                  epochs = 30)#30
# Out:
# Epoch 1/30
# 100/100 [==============================] - 72s 723ms/step - loss: 0.3361 - precision: 0.5340 - recall: 0.3651 - fbeta_score: 0.4757 - acc: 0.9168 - val_loss: 0.2184 - val_precision: 0.5125 - val_recall: 0.4196 - val_fbeta_score: 0.4898 - val_acc: 0.9183
# Epoch 2/30
# 100/100 [==============================] - 66s 664ms/step - loss: 0.2286 - precision: 0.5293 - recall: 0.3069 - fbeta_score: 0.4506 - acc: 0.9171 - val_loss: 0.1977 - val_precision: 0.5781 - val_recall: 0.4956 - val_fbeta_score: 0.5585 - val_acc: 0.9306
# Epoch 3/30
# 100/100 [==============================] - 74s 739ms/step - loss: 0.2215 - precision: 0.5404 - recall: 0.3639 - fbeta_score: 0.4885 - acc: 0.9201 - val_loss: 0.2154 - val_precision: 0.5312 - val_recall: 0.4332 - val_fbeta_score: 0.5077 - val_acc: 0.9213
# Epoch 4/30
# 100/100 [==============================] - 66s 656ms/step - loss: 0.2258 - precision: 0.5401 - recall: 0.3377 - fbeta_score: 0.4648 - acc: 0.9178 - val_loss: 0.2247 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_fbeta_score: 0.0000e+00 - val_acc: 0.9137
# Epoch 5/30
# 100/100 [==============================] - 66s 663ms/step - loss: 0.2187 - precision: 0.5313 - recall: 0.3455 - fbeta_score: 0.4741 - acc: 0.9190 - val_loss: 0.2262 - val_precision: 0.5281 - val_recall: 0.4228 - val_fbeta_score: 0.5014 - val_acc: 0.9179
# Epoch 6/30
# 100/100 [==============================] - 65s 647ms/step - loss: 0.2215 - precision: 0.5275 - recall: 0.3353 - fbeta_score: 0.4648 - acc: 0.9186 - val_loss: 0.2088 - val_precision: 0.5563 - val_recall: 0.4629 - val_fbeta_score: 0.5335 - val_acc: 0.9246
# Epoch 7/30
# 100/100 [==============================] - 67s 666ms/step - loss: 0.2236 - precision: 0.5312 - recall: 0.3426 - fbeta_score: 0.4716 - acc: 0.9182 - val_loss: 0.2191 - val_precision: 0.5133 - val_recall: 0.4178 - val_fbeta_score: 0.4903 - val_acc: 0.9190
# Epoch 8/30
# 100/100 [==============================] - 66s 657ms/step - loss: 0.2185 - precision: 0.5202 - recall: 0.2963 - fbeta_score: 0.4472 - acc: 0.9179 - val_loss: 0.2242 - val_precision: 0.5344 - val_recall: 0.4199 - val_fbeta_score: 0.5057 - val_acc: 0.9181
# Epoch 9/30
# 100/100 [==============================] - 65s 648ms/step - loss: 0.2180 - precision: 0.5451 - recall: 0.3953 - fbeta_score: 0.5025 - acc: 0.9213 - val_loss: 0.2263 - val_precision: 0.5062 - val_recall: 0.3973 - val_fbeta_score: 0.4791 - val_acc: 0.9152
# Epoch 10/30
# 100/100 [==============================] - 64s 642ms/step - loss: 0.2197 - precision: 0.5334 - recall: 0.3747 - fbeta_score: 0.4851 - acc: 0.9201 - val_loss: 0.2262 - val_precision: 0.5366 - val_recall: 0.4235 - val_fbeta_score: 0.5076 - val_acc: 0.9185
# Epoch 11/30
# 100/100 [==============================] - 63s 632ms/step - loss: 0.2209 - precision: 0.5336 - recall: 0.3649 - fbeta_score: 0.4846 - acc: 0.9191 - val_loss: 0.2165 - val_precision: 0.5469 - val_recall: 0.4397 - val_fbeta_score: 0.5202 - val_acc: 0.9217
# Epoch 12/30
# 100/100 [==============================] - 69s 688ms/step - loss: 0.2252 - precision: 0.5079 - recall: 0.2797 - fbeta_score: 0.4310 - acc: 0.9155 - val_loss: 0.2269 - val_precision: 0.5219 - val_recall: 0.4277 - val_fbeta_score: 0.4977 - val_acc: 0.9175
# Epoch 13/30
# 100/100 [==============================] - 67s 673ms/step - loss: 0.2155 - precision: 0.5484 - recall: 0.4094 - fbeta_score: 0.5116 - acc: 0.9218 - val_loss: 0.2085 - val_precision: 0.5375 - val_recall: 0.4561 - val_fbeta_score: 0.5179 - val_acc: 0.9235
# Epoch 14/30
# 100/100 [==============================] - 65s 653ms/step - loss: 0.2161 - precision: 0.5464 - recall: 0.4082 - fbeta_score: 0.5097 - acc: 0.9223 - val_loss: 0.2183 - val_precision: 0.5437 - val_recall: 0.4365 - val_fbeta_score: 0.5172 - val_acc: 0.9210
# Epoch 15/30
# 100/100 [==============================] - 65s 651ms/step - loss: 0.2108 - precision: 0.5617 - recall: 0.3870 - fbeta_score: 0.5049 - acc: 0.9249 - val_loss: 0.2133 - val_precision: 0.5125 - val_recall: 0.4289 - val_fbeta_score: 0.4925 - val_acc: 0.9204
# Epoch 16/30
# 100/100 [==============================] - 66s 660ms/step - loss: 0.2137 - precision: 0.5653 - recall: 0.4187 - fbeta_score: 0.5248 - acc: 0.9242 - val_loss: 0.2305 - val_precision: 0.4820 - val_recall: 0.3715 - val_fbeta_score: 0.4538 - val_acc: 0.9113
# Epoch 17/30
# 100/100 [==============================] - 67s 666ms/step - loss: 0.2179 - precision: 0.5338 - recall: 0.3564 - fbeta_score: 0.4816 - acc: 0.9191 - val_loss: 0.1924 - val_precision: 0.6059 - val_recall: 0.5053 - val_fbeta_score: 0.5807 - val_acc: 0.9350
# Epoch 18/30
# 100/100 [==============================] - 65s 647ms/step - loss: 0.2132 - precision: 0.5678 - recall: 0.4400 - fbeta_score: 0.5348 - acc: 0.9246 - val_loss: 0.2161 - val_precision: 0.5469 - val_recall: 0.4450 - val_fbeta_score: 0.5218 - val_acc: 0.9213
# Epoch 19/30
# 100/100 [==============================] - 65s 646ms/step - loss: 0.2169 - precision: 0.5574 - recall: 0.3828 - fbeta_score: 0.5034 - acc: 0.9213 - val_loss: 0.2025 - val_precision: 0.5906 - val_recall: 0.5014 - val_fbeta_score: 0.5687 - val_acc: 0.9308
# Epoch 20/30
# 100/100 [==============================] - 64s 645ms/step - loss: 0.2201 - precision: 0.5286 - recall: 0.3316 - fbeta_score: 0.4676 - acc: 0.9184 - val_loss: 0.2184 - val_precision: 0.5498 - val_recall: 0.4335 - val_fbeta_score: 0.5204 - val_acc: 0.9208
# Epoch 21/30
# 100/100 [==============================] - 65s 647ms/step - loss: 0.2222 - precision: 0.5292 - recall: 0.3243 - fbeta_score: 0.4623 - acc: 0.9184 - val_loss: 0.2093 - val_precision: 0.6522 - val_recall: 0.1798 - val_fbeta_score: 0.4195 - val_acc: 0.9240
# Epoch 22/30
# 100/100 [==============================] - 70s 700ms/step - loss: 0.2170 - precision: 0.5483 - recall: 0.3458 - fbeta_score: 0.4689 - acc: 0.9210 - val_loss: 0.2188 - val_precision: 0.5529 - val_recall: 0.3823 - val_fbeta_score: 0.5049 - val_acc: 0.9206
# Epoch 23/30
# 100/100 [==============================] - 64s 641ms/step - loss: 0.2079 - precision: 0.5551 - recall: 0.3941 - fbeta_score: 0.5092 - acc: 0.9235 - val_loss: 0.2246 - val_precision: 0.5186 - val_recall: 0.3982 - val_fbeta_score: 0.4878 - val_acc: 0.9177
# Epoch 24/30
# 100/100 [==============================] - 65s 652ms/step - loss: 0.2147 - precision: 0.5608 - recall: 0.3797 - fbeta_score: 0.5064 - acc: 0.9220 - val_loss: 0.2265 - val_precision: 0.5583 - val_recall: 0.2564 - val_fbeta_score: 0.4444 - val_acc: 0.9158
# Epoch 25/30
# 100/100 [==============================] - 65s 654ms/step - loss: 0.2187 - precision: 0.5558 - recall: 0.3469 - fbeta_score: 0.4898 - acc: 0.9209 - val_loss: 0.2132 - val_precision: 0.5487 - val_recall: 0.3730 - val_fbeta_score: 0.4970 - val_acc: 0.9217
# Epoch 26/30
# 100/100 [==============================] - 67s 666ms/step - loss: 0.2151 - precision: 0.5560 - recall: 0.3812 - fbeta_score: 0.5058 - acc: 0.9222 - val_loss: 0.2295 - val_precision: 0.4917 - val_recall: 0.3122 - val_fbeta_score: 0.4398 - val_acc: 0.9106
# Epoch 27/30
# 100/100 [==============================] - 66s 664ms/step - loss: 0.2216 - precision: 0.5421 - recall: 0.3202 - fbeta_score: 0.4703 - acc: 0.9187 - val_loss: 0.2045 - val_precision: 0.5461 - val_recall: 0.4345 - val_fbeta_score: 0.5186 - val_acc: 0.9252
# Epoch 28/30
# 100/100 [==============================] - 64s 643ms/step - loss: 0.2159 - precision: 0.5539 - recall: 0.3661 - fbeta_score: 0.4978 - acc: 0.9218 - val_loss: 0.2208 - val_precision: 0.5493 - val_recall: 0.3953 - val_fbeta_score: 0.5071 - val_acc: 0.9216
# Epoch 29/30
# 100/100 [==============================] - 64s 645ms/step - loss: 0.2231 - precision: 0.5486 - recall: 0.3160 - fbeta_score: 0.4713 - acc: 0.9202 - val_loss: 0.2115 - val_precision: 0.5773 - val_recall: 0.3274 - val_fbeta_score: 0.4957 - val_acc: 0.9238
# Epoch 30/30
# 100/100 [==============================] - 66s 663ms/step - loss: 0.2255 - precision: 0.5211 - recall: 0.2095 - fbeta_score: 0.3883 - acc: 0.9161 - val_loss: 0.2147 - val_precision: 0.5738 - val_recall: 0.1921 - val_fbeta_score: 0.3981 - val_acc: 0.9219

# %%
score = multi_disease_model.evaluate(test_X, test_Y)
print('Test accuracy:', score[1])

# %%
print(score)

# %%
plt.plot(history.history['acc'], label='training accuracy')
plt.plot(history.history['val_acc'], label='test accuracy')
plt.legend()
plt.title('Multiclass classification CNN accuracy per epoch')
plt.show()

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='test loss')
plt.legend()
plt.title('loss per epoch')
plt.show()
